# %% [markdown]
# <a href="https://colab.research.google.com/github/kimyunha1/OSP_project/blob/yunha/Project_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt roboflow onnx onnxruntime
# !wget https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 18359, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 18359 (delta 34), reused 18 (delta 18), pack-reused 18305 (from 2)
# Receiving objects: 100% (18359/18359), 17.47 MiB | 20.26 MiB/s, done.
# Resolving deltas: 100% (12478/12478), done.
# /content/yolov5/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 89.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 142.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
# ...

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="6yKgD9MhrdcQlM8POOOJ")
project = rf.workspace("yunha-s-workspace").project("osp_project")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to OSP_project-1 in yolov5pytorch:: 100%|██████████| 803/803 [00:00<00:00, 9884.47it/s]

# %%
# !python train.py --img 640 --batch 64 --epochs 300 --data OSP_project-1/data.yaml --weights yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: WARNING W&B disabled due to login timeout.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source OSP_project-1/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=OSP_project-1/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-503-gb8493964 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/17 /content/yolov5/OSP_project-1/test/images/KakaoTalk_20260616_210656156_03_jpg.rf.90d09169656b7c42152c0af60ff3f897.jpg: 640x640 1 normal, 9.9ms
# ...

# %%
# !python export.py --weights runs/train/exp/weights/best.pt --include onnx
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-503-gb8493964 Python-3.12.13 torch-2.11.0+cu128 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov5/yolov5/export.py", line 1542, in <module>
#     main(opt)
#   File "/content/yolov5/yolov5/export.py", line 1537, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/yolov5/export.py", line 1382, in run
# ...
